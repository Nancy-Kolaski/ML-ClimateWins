# %% [markdown]
# # 2.1 Unsupervised - Dendrograms w/REDUCED DATA - NK

# %% [markdown]
# ## This script contains the following:
# 1) Import libraries and data (reduced data and pleasant weather answers data set)
# 2) Scaling (2010)
# 3) Dendrograms
# 4) Principal Component Analysis (PCA)

# %% [markdown]
# ## Import libraries & datasets: climate and reduced answers (2010_PCA )

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# import path
path = r'/Users/nancykray/Desktop/CF/Machine Learning /ClimateWins/Data Sets'

# %% [markdown]
# #### Import climate (weather predictions) -> X data

# %%
# import the scaled European weather data
climate = pd.read_csv(os.path.join(path, 'DATASET weather_prediction_dataset_processed.csv'))

# %%
climate.shape
# Out:
# (22950, 170)

# %% [markdown]
# #### Import reduced weather data for 2010 -> Y data

# %%
reduced =  pd.read_csv (os.path.join(path, '2010_PCA.csv'), index_col = False)

# %%
reduced.head()
# Out:
#         PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0  -8.126576 -2.138915 -3.966428 -0.060814  0.028138  3.037520  1.503975
# 1 -10.565505  0.540660 -4.616451 -0.565368 -2.784018  1.227919  3.055841
# 2 -11.026152  4.167419 -1.905376  0.781945 -3.886878 -0.313349  0.398458
# 3 -10.951613  4.408962  1.281137 -0.749496 -4.026034 -2.153766 -0.744334
# 4 -11.114522  2.976581  3.241646 -2.059285 -3.721282 -2.714744 -0.438471
#
#        PCA8      PCA9
# 0 -4.177647  1.789402
# 1 -4.542659  1.734645
# 2 -5.369374 -0.036747
# 3 -2.707100  0.444699
# 4 -1.242425  1.488578

# %% [markdown]
# ### 2) Re-run Dendrogram code with Reduced Dataset

# %% [markdown]
# ### Single method: reduced data 2010

# %%
distance_single = linkage(reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9']],method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Single Method",fontsize=18)
plt.show()

# %% [markdown]
# ### Complete method: reduced data 2010

# %%
distance_single = linkage(reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9']],method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Complete Method",fontsize=18)
plt.show()

# %% [markdown]
# ### Average Method: reduced data 2010

# %%
distance_single = linkage(reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9']],method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Average Method",fontsize=18)
plt.show()

# %% [markdown]
# ### Ward Method: reduced data 2010

# %%
distance_single = linkage(reduced.loc[:,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6',
'PCA7',
'PCA8',
'PCA9']],method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Ward Method",fontsize=18)
plt.show()
